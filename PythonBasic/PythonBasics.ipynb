# %%
age = 20
if age >= 18:
    print("You are an adult")

# %%
age = 15
if age >= 18:
    print("You are an adult")
    pass;

# %%
age = 15
if age >= 18:
    print("You are an adult")
else:
    print("You are a minor")

# %%
age = 20
has_id = True

if age >= 18:
    if has_id:
        print("Entry allowed")
    else:
        print("ID required")
else:
    print("Too young")

# %%
marks = 75

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
else:
    print("Fail")

# %%
marks = 75

if marks >= 90:
    "grade" = "A"
elif marks >= 80:
    "grade" = "B"
elif marks >= 70:
    "grade" = "C"
elif marks >= 60:
    "grade" = "D"
else:
    "grade" = "fail"

print(grade)

# %%
age = 20
has_license = True
if age >= 19 and has_license:
    print("You can drive")

# %%
age = 20
has_license = True
if age >= 19 and has_license:
    print("You can drive")
else:
        print("You need a license")

# %%
age = 20
result = "Adult" if age >= 18 else "Minor"
print(result)

# %%
x = int(input("Obtained Marks:"))
if x >= 90:
    result = "A"
elif x >= 80:
    result = "B"
elif x >= 70:
    result = "C"
else:
    result = "D"

print(result)

# %%
count = 0
while count < 5:
    print(count)
    count += 1

# %%
numbers = [10,20, 30, 40]

for number in numbers:
    print(numbers)

# %%
count = 0
while count < 5:
    print(count)
    count += 1

# %%
for i in range(10):
    if i == 5:
        break
    print(i)

# %%
for numbers in range(1, 6):
    pass

# %%
for i in range(1, 6):
    if i % 2 == 0:
        continue
    print(i)

# %%
def multiply(a, b=3):
    return a * b

print(multiply(5))
print(multiply(5, 2))

# %%
try:
    num = int(input("Enter a number: "))
    print(10 / num)
except ValueError:
    print("That's not a valid number")
except ZeroDivisionError:
    print("Can't divide by zero")

# %%
for numbers in range(5):
    print(number)
else:
    print("Loop Completed")

# %%
for numbers in range(5):
    if number == 2:
        break
else:
    print("Loop Completed")

# %%
x = 2
def square(x):
    return x**2

# %%
square = lambda x: x ** 2

# %%
students = ["Ali", "Ahmed", "Sara", "Usman"]
print(students[0])
print(students[2])
print(students[-1])

# %%
# append() — adds to the end
students = ["Ali", "Ahmed"]
students.append("Sara")
print(students)

# insert() — adds at a specific position
students = ["Ali", "Ahmed", "Sara"]
students.insert(1, "Hamza")
print(students)

# %%
#lambda with multiple parameters
add_three = lambda a, b, c: a + b + c

print(add_three(5, 10, 15))  # Output: 30

# %%
students = [
    ("Ali",80),
    ("Ahmad",75),
    ("Sara",85),
]

students.sort(key=lambda student: student[1])
print(students)

# %%
numbers = [1, 2, 3, 4]

result = map(lambda x: x**2, numbers)
print(tuple(result))

# %%
numbers = [1, 2, 3, 4]

result = map(lambda x: x**2, numbers)
print(list(result))

# %%
numbers = [1, 2, 3, 4]

result = map(lambda x: x**2, numbers)
print(result)

# %%
def square (x):
    return x ** 2
numbers = [1, 2, 3, 4, 5]

result = map(square, numbers)
print(list(result))

# %%
a = [1, 2, 3]
b = [10, 20, 30]

result = map(lambda x, y: x + y, a,b)
print(list(result))

# %%
def multiplier (factor):
    def multiply(number):
        return number *factor
    return multiply

# %%
with open ("output.txt","w") as file:
    file.write("Hello Python")

# %%
with open ("C:\Users\MONEEM\Documents\test.txt","w") as file:
    file.write("Hello Python")

# %%
with open("C:/Users/MONEEM/Documents/test.txt", "w") as file:
    file.write("Hello Python")

# %%
try:
    number = 10/0
except ZeroDivisionError:
    print("Cannot Divide by zero")

# %%
students = ["Ali", "Ahmed", "Sara", "Usman"]
print(students[0])
print(students[2])
print(students[-1])

# %%
students = ["Ali", "Ahmed", "Sara"]
students[1] = "Hamza"
print(students)

# %%
# append() — adds to the end
students = ["Ali", "Ahmed"]
students.append("Sara")
print(students)

# insert() — adds at a specific position
students = ["Ali", "Ahmed", "Sara"]
students.insert(1, "Hamza")
print(students)

# %%
nums = [10, 20, 30]
nums.insert(0, 40)
print(nums)

# %%
nums = [10, 20, 30]
nums.append(40)
print(nums)

# %%
nums = [10, 20, 30, 40]
nums.remove(30) #remove the first occurance of item
print(nums)

# %%
nums = [10, 20, 30, 40]
nums.remove(30)
print(nums)

x = nums.pop()     # removes AND returns the last item
print(x)
print(nums)
nums.pop(1)         # you can also pop() a specific index

# %%
numbers = [10, 20, 30, 40]
del numbers[2]
print(numbers)

numbers.clear()         # wipes the entire list
print(numbers)

# %%
nums = [10, 20, 30, 40, 50]
print(nums[1:4])

# %%
nums = [10, 20, 30, 40, 50]
print(nums[1:4])

print(nums[0:5:2])

# %%
class Car:
    def drive(self):
        print("Car is driving")
car1 = Car()

car1.drive()

# %%
class Students:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
student1 = Students("Ali", 20)
student2 = Students("Ahmad", 22)

print(student1.name, student1.age)
print(student2.name, student2.age)

# %%
class Student:
    def __init__ (self, name):
        self.name = name

    def introduce(self):
        print(f"My name is {self.name}")

student = Student("Ali")

student.introduce()

# %%
class Student:
    # 1. Needs double underscores __init__
    def __init__(self, name):
        self.name = name

    def introduce(self):
        print(f"My name is {self.name}")

student = Student("Ali")
student.introduce()

# %%
class Student:
    school = "ABC School"

    def __init__ (self, name):
        self.name = name
    if name == "ALI"
    self.school = name

s1 = Student("Ali")
s2 = Student("Ahmad")

print(s1.school)
print(s2.school)

# %%
class Student:
    school = "ABC School"

    def __init__ (self, name):
        self.name = name

    @classmethod
    def change_school(cls, new_school):
        cls.school = new_school

Student.change_school("XYZ School")
print(Student.school)

# %%
class Math
    @staticmethod
    def add(a,b):
        return a+b
print(Math.add(10,20)

# %%
class BankAccount:
    def __init__ (self, balance):
        self.balance=balance
    def deposit(self,amount):
        if amount>0:
            self.balance += amount
    def get_balance(self):
        return self.balance

account=BankAccount(1000)


print(f"Initial Balance: ${account.get_balance()}")
account.deposit(500)
print(f"Balance after deposit: ${account.get_balance()}")

# %%
# Demonstrating how it works:
print(f"Initial Balance: ${account.get_balance()}")

# Depositing money
account.deposit(500)
print(f"Balance after deposit: ${account.get_balance()}")

# %%
class Student:
    def __init__(self):
        self.__name = "Ali"

student = Student()

print(student._Student__name)

# %%
class Student:
    def __init__(self):
        # 1. Added a dot after self to attach the private variable
        self.__name = "Ahmad" 

s = Student()

# This will fail! Python hid the variable to make it "private".
# print(s.__name)  # AttributeError: 'Student' object has no attribute '__name'

# 2. Name Mangling in action: How to actually access it from outside
print(s._Student__name)

# %%
#Abstraction
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Dog(Animal):
    def sound(self):
        print("Bark")

dog = Dog()
dog.sound()

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Dog(Animal):
    def sound(self): # if we removed this, it would pass the error
        print("Bark")

dog = Dog()
dog.sound()

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius ** 2

circle = Circle(5)
print(circle.area())

# %%
class Animal:
    def eat(self):
        print("Eating")

class Dog(Animal):
    def bark(self):
        print("Barking")

class Cat(Animal):
    def meow(self):
        print("Meow")

dog1 = Dog()
dog1.eat()
dog1.bark()

cat1 = Cat()
cat1.eat()
cat1.meow()

# %%
class Calculator:

    def add(self, a, b, c=0):
        return a + b + c

calculator = Calculator()

print(calculator.add(1, 2))
print(calculator.add(1, 2, 3))
